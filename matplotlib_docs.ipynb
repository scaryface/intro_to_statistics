# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
t = 100
x_axis = np.linspace(0,np.math.pi, np.math.pi*t)
plt.plot(x_axis, np.array([np.math.sin(x) for x in x_axis]))
plt.axis([x_axis[0], x_axis[-1], 0, 1])
plt.show()
